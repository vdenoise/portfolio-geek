# %% [raw]
# ---
# title: Démarrer
# categories: [tutoriel, 101, fr]
# date: "3/1/2023"
# format:
#     html: default
# ---

# %% [markdown]
# ::: {.content-hidden when-profile="presentation"}
# # Hello guys
#
# :::

# %%
#| echo: False
# Ceci est du code qui ne sort sur les slides
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import os

import matplotlib.dates as mdates
import seaborn as sns
import numpy as np
from scipy.stats import norm
import math
import seaborn as sns

tpl_path = "https://github.com/vdenoise/templates/raw/master"
mpl_tpl_path = f"{tpl_path}/matplotlib"

# %% [markdown]
# ![](/pictures/paraglider-starting-takeoff.png)

# %%
# %%capture
tickers = ['SPY']
start_date = '2018-09-14'
end_date = '2022-09-14'
tickers = ['SPY', 'AGG']
#yf.pdr_override(tickers)
df = yf.download(tickers,  start=start_date, end=end_date)
data = df.Close.SPY.resample("B").last().fillna(method="bfill")
data_agg = df.Close.AGG.resample("B").last().fillna(method="bfill")

# %% [markdown]
# ## Slide 1
# ::: {.container}
# :::: {.col id="left"}

# %%
plt.style.use(f"{mpl_tpl_path}/dracula_slide.mplstyle")
data.resample("W").last().plot();
plt.ylabel("Wealth Curve")
# Out:
# Text(0, 0.5, 'Wealth Curve')

# %% [markdown]
# ::::
# :::

# %% [markdown]
# ## Titre 1
#
# ::: {.container}
# :::: {.col id="left"}
#
# - Pret ou pas pret, Il faut bien démarrer quelque part!
# ::::
# :::
#
#
# ## Main Title
#
# ::: {.container}
# :::: {.col id="left"}
#
# - Test Bullet a Gauche
# - Test Bullet a Gauche
# - Test Bullet a Gauche
#
# ::::
# :::
#
#
#
# ::: {.notes}
#
# Bonjour a tous, et merci de nous accompagner pour ce premier épisode!
# Dans cette vidéo nous allons faire un tour d'horizon sur l'analyse de données financières.
# Ce sera uniquement un tour d'horizon, et aucune connaissance préalable n'est requise pour suivre cette vidéo.
#
# L'objectif est clair et simple: savoir suivre la performance de différents actifs financiers. Pour ceci, nous allons nous intéresser a la performance de certains indices, dont nous allons approximer la performance par celle d'ETFs, qui sont progressivement devenus des outils indispensable pour de nombreux investisseurs. Petit rappel nécessaire, je ne suis pas conseiller financier, je ne donne aucune recommendation ni conseil, mon seul objectif ici est d'utiliser des informations pour analyser les marchés.
#
# :::
#
#
# ## Titre 2
#
#
# ## Titre 3
