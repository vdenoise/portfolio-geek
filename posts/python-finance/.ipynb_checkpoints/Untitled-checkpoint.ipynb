# %%
# !pip install bt
# Out:
# Collecting bt
#   Downloading bt-1.1.0-cp38-cp38-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Collecting ffn>=1.1.0 (from bt)
#   Using cached ffn-1.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyprind>=2.11 (from bt)
#   Using cached PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting tqdm>=4 (from bt)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: decorator>=5.0.7 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from ffn>=1.1.0->bt) (5.1.1)
# Requirement already satisfied: matplotlib>=1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from ffn>=1.1.0->bt) (3.7.5)
# Requirement already satisfied: numpy in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from ffn>=1.1.0->bt) (1.24.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from ffn>=1.1.0->bt) (2.0.3)
# Collecting scikit-learn>=0.15 (from ffn>=1.1.0->bt)
#   Downloading scikit_learn-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: scipy>=0.15 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from ffn>=1.1.0->bt) (1.10.1)
# Collecting tabulate>=0.7.5 (from ffn>=1.1.0->bt)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: yfinance>=0.2 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from ffn>=1.1.0->bt) (0.2.52)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from matplotlib>=1->ffn>=1.1.0->bt) (6.3.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from pandas>=0.19->ffn>=1.1.0->bt) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from pandas>=0.19->ffn>=1.1.0->bt) (2025.1)
# Collecting joblib>=1.1.1 (from scikit-learn>=0.15->ffn>=1.1.0->bt)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.15->ffn>=1.1.0->bt)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from yfinance>=0.2->ffn>=1.1.0->bt) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2->ffn>=1.1.0->bt) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from html5lib>=1.1->yfinance>=0.2->ffn>=1.1.0->bt) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from html5lib>=1.1->yfinance>=0.2->ffn>=1.1.0->bt) (0.5.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=1->ffn>=1.1.0->bt) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from requests>=2.31->yfinance>=0.2->ffn>=1.1.0->bt) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from requests>=2.31->yfinance>=0.2->ffn>=1.1.0->bt) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from requests>=2.31->yfinance>=0.2->ffn>=1.1.0->bt) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Caskroom/miniconda/base/envs/portfolio-geek/lib/python3.8/site-packages (from requests>=2.31->yfinance>=0.2->ffn>=1.1.0->bt) (2024.12.14)
# Downloading bt-1.1.0-cp38-cp38-macosx_10_9_x86_64.whl (261 kB)
# Using cached ffn-1.1.1-py3-none-any.whl (26 kB)
# Using cached PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-macosx_10_9_x86_64.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 26.9 MB/s eta 0:00:001m29.7 MB/s eta 0:00:01
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: pyprind, tqdm, threadpoolctl, tabulate, joblib, scikit-learn, ffn, bt
# Successfully installed bt-1.1.0 ffn-1.1.1 joblib-1.4.2 pyprind-2.11.3 scikit-learn-1.3.2 tabulate-0.9.0 threadpoolctl-3.5.0 tqdm-4.67.1

# %%
import bt
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------------------
# 1. Download data from yfinance
# -----------------------------------------
tickers = ["SPY", "TLT"]
start_date = "2015-01-01"
end_date = "2022-12-31"

data = yf.download(tickers, start=start_date, end=end_date)["Close"].dropna()

# -----------------------------------------
# 2. Define the two strategies
# -----------------------------------------

# Strategy A: Monthly Rebalanced 50/50
monthly_rebalance_strategy = bt.Strategy(
    "Monthly Rebalanced 50/50",
    [
        bt.algos.RunMonthly(),
        bt.algos.SelectAll(),
        bt.algos.WeighSpecified(SPY=0.5, TLT=0.5),
        bt.algos.Rebalance(),
    ],
)

# Strategy B: Buy-and-Hold 50/50
buy_and_hold_strategy = bt.Strategy(
    "Buy & Hold 50/50",
    [
        bt.algos.RunOnce(),
        bt.algos.SelectAll(),
        bt.algos.WeighSpecified(SPY=0.5, TLT=0.5),
        bt.algos.Rebalance(),
    ],
)

# -----------------------------------------
# 3. Create Backtests
# -----------------------------------------
test_monthly_rebalanced = bt.Backtest(monthly_rebalance_strategy, data)
test_buy_and_hold = bt.Backtest(buy_and_hold_strategy, data)

# -----------------------------------------
# 4. Run backtests
# -----------------------------------------
results = bt.run(test_monthly_rebalanced, test_buy_and_hold)

# -----------------------------------------
# 5. Inspect & Plot performance
# -----------------------------------------
# Print summary stats
print(results)  # shows performance metrics

# Plot normalized (cumulative) returns
ax = results.plot(title="Monthly Rebalanced vs. Buy & Hold 50/50", figsize=(10, 6))
ax.set_ylabel("Cumulative Returns")
plt.show()

# -----------------------------------------
# 6. Plot weights
# -----------------------------------------
# Option A: Directly use the backtest objects
monthly_rebalanced_weights = test_monthly_rebalanced.get_weights()
buy_and_hold_weights = test_buy_and_hold.get_weights()

fig, axes = plt.subplots(nrows=2, figsize=(10, 6), sharex=True)

monthly_rebalanced_weights.plot.area(ax=axes[0], title="Monthly Rebalanced Weights")
buy_and_hold_weights.plot.area(ax=axes[1], title="Buy & Hold Weights")

plt.tight_layout()
plt.show()

# -----------------------------------------
# Alternative approach for plotting weights
# via results object (just for reference):
# monthly_rebalanced_weights = results['Monthly Rebalanced 50/50'].backtest.get_weights()
# buy_and_hold_weights = results['Buy & Hold 50/50'].backtest.get_weights()
# (Then plot these dataframes as above)
# -----------------------------------------
# Out:
#   File "/var/folders/pm/cq1rc4217fzf1sww8bpsq2rh0000gn/T/ipykernel_541/3703094470.py", line 13
#     data = yf.download(tickers, start=start_date, end=end_date)["
#                                                                  ^
# SyntaxError: EOL while scanning string literal
